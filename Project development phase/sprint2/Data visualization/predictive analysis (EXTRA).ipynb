# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/crop_production.csv')

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
plt.scatter(df.State_Name,df.District_Name)

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#           Crop_Year           Area    Production
# count  34297.000000   34296.000000  3.421300e+04
# mean    2005.961338    7381.595611  5.929376e+05
# std        5.122459   28578.280400  1.486502e+07
# min     1997.000000       0.200000  0.000000e+00
# 25%     2002.000000      90.000000  1.120000e+02
# 50%     2006.000000     505.500000  8.070000e+02
# 75%     2011.000000    2704.250000  6.800000e+03
# max     2014.000000  877029.000000  7.801620e+08

# %%
df.shape
# Out:
# (246091, 7)

# %%
#independent variable
x=df.iloc[:,0:1]
x
# Out:
#                          State_Name
# 0       Andaman and Nicobar Islands
# 1       Andaman and Nicobar Islands
# 2       Andaman and Nicobar Islands
# 3       Andaman and Nicobar Islands
# 4       Andaman and Nicobar Islands
# ...                             ...
# 246086                  West Bengal
# 246087                  West Bengal
# 246088                  West Bengal
# 246089                  West Bengal
# 246090                  West Bengal
#
# [246091 rows x 1 columns]

# %%
y=df.iloc[:,1:]
y
# Out:
#        District_Name  Crop_Year       Season                 Crop      Area  \
# 0           NICOBARS       2000  Kharif                  Arecanut    1254.0
# 1           NICOBARS       2000  Kharif       Other Kharif pulses       2.0
# 2           NICOBARS       2000  Kharif                      Rice     102.0
# 3           NICOBARS       2000  Whole Year                Banana     176.0
# 4           NICOBARS       2000  Whole Year             Cashewnut     720.0
# ...              ...        ...          ...                  ...       ...
# 246086       PURULIA       2014  Summer                      Rice     306.0
# 246087       PURULIA       2014  Summer                   Sesamum     627.0
# 246088       PURULIA       2014  Whole Year             Sugarcane     324.0
# 246089       PURULIA       2014  Winter                      Rice  279151.0
# 246090       PURULIA       2014  Winter                   Sesamum     175.0
#
#         Production
# 0           2000.0
# 1              1.0
# 2            321.0
# 3            641.0
# 4            165.0
# ...            ...
# 246086       801.0
# 246087       463.0
# 246088     16250.0
# 246089    597899.0
# 246090        88.0
#
# [246091 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (196872, 1)

# %%
x_test.shape
# Out:
# (49219, 1)

# %%
x_test
# Out:
#                          State_Name
# 222211                Uttar Pradesh
# 148500                       Odisha
# 40239                         Bihar
# 117     Andaman and Nicobar Islands
# 64394                       Gujarat
# ...                             ...
# 48410                  Chhattisgarh
# 234245                  Uttarakhand
# 179097                   Tamil Nadu
# 169648                    Rajasthan
# 233866                  Uttarakhand
#
# [49219 rows x 1 columns]

# %%
y_test
# Out:
#                    District_Name  Crop_Year       Season           Crop  \
# 222211                       MAU       2001  Kharif       Small millets
# 148500                   BARGARH       2007  Winter           Sugarcane
# 40239            PURBI CHAMPARAN       2010  Kharif               Mesta
# 117     NORTH AND MIDDLE ANDAMAN       2010  Rabi          Dry chillies
# 64394              SURENDRANAGAR       1997  Kharif               Bajra
# ...                          ...        ...          ...            ...
# 48410                  DANTEWADA       2012  Whole Year    Dry chillies
# 234245                  NAINITAL       2013  Whole Year          Garlic
# 179097                DHARMAPURI       2005  Kharif        Cotton(lint)
# 169648                 DUNGARPUR       2001  Whole Year        Sannhamp
# 233866                  NAINITAL       2000  Rabi                  Gram
#
#            Area  Production
# 222211     98.0        51.0
# 148500    742.0     47581.5
# 40239       7.0       120.0
# 117       254.0       402.0
# 64394   85900.0    103000.0
# ...         ...         ...
# 48410      65.0        48.0
# 234245    128.0       181.0
# 179097   6580.0     11325.0
# 169648    210.0        58.0
# 233866    458.0       297.0
#
# [49219 rows x 6 columns]

# %%
x_train
# Out:
#             State_Name
# 159870          Odisha
# 16917            Assam
# 37429            Bihar
# 130347     Maharashtra
# 51448     Chhattisgarh
# ...                ...
# 176963          Sikkim
# 117952  Madhya Pradesh
# 173685       Rajasthan
# 43567            Bihar
# 199340   Uttar Pradesh
#
# [196872 rows x 1 columns]

# %%
y_train
# Out:
#         District_Name  Crop_Year       Season                Crop      Area  \
# 159870        SONEPUR       2015  Winter        Moong(Green Gram)    1478.0
# 16917       DIBRUGARH       2008  Whole Year             Turmeric     100.0
# 37429     MUZAFFARPUR       2002  Rabi         Other  Rabi pulses     125.0
# 130347          JALNA       2007  Kharif                    Bajra     517.0
# 51448          KANKER       2001  Kharif                     Rice  164934.0
# ...               ...        ...          ...                 ...       ...
# 176963  EAST DISTRICT       1998  Rabi                      Wheat    2720.0
# 117952         RATLAM       2002  Whole Year               Tomato     232.0
# 173685         NAGAUR       2000  Whole Year            Coriander     718.0
# 43567         SHEOHAR       2009  Kharif            Small millets       9.0
# 199340      ALLAHABAD       2001  Rabi                    Linseed    2463.0
#
#         Production
# 159870       452.3
# 16917         57.0
# 37429         84.0
# 130347       554.0
# 51448     262672.0
# ...            ...
# 176963      2370.0
# 117952         0.0
# 173685        73.0
# 43567          7.0
# 199340       882.0
#
# [196872 rows x 6 columns]

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]>

# %%
cor=df.corr()
cor
# Out:
#             Crop_Year      Area  Production
# Crop_Year    1.000000 -0.026022    0.006989
# Area        -0.026022  1.000000    0.040587
# Production   0.006989  0.040587    1.000000

# %%
import seaborn as sns
sns.heatmap(cor,annot=True)

# %%
df['State_Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
var = 'Production'
plt.scatter(x = df[var], y = df['Crop'])
plt.grid(True)

# %%
var = 'Production'
plt.scatter(x = df[var], y = df['Area'])
plt.grid(True)

# %%
var = 'Crop'
plt.scatter(x = df[var], y = df['Area'])
plt.grid(True)
